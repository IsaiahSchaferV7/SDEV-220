# %% [markdown]
# 3.1
#
# How many seconds are in an hour? Use the interactive interpreter as a calculator and multiply the number of seconds in a minute (60) by the number of minutes in an hour (also 60).

# %%
SECONDS: int = 60
MINUTES: int = 60
print(f"The amount of seconds in an hour is: {SECONDS * MINUTES}")
# Out:
# The amount of seconds in an hour is: 3600

# %% [markdown]
# 3.2
#
# Assign the result from the previous task (seconds in an hour) to a variable called seconds_per_hour.

# %%
SECONDS_PER_HOUR: int = SECONDS * MINUTES

# %% [markdown]
# 3.3
#
# How many seconds are in a day? Use your seconds_per_hour variable.

# %%
HOURS_PER_DAY: int = 24

print(f"The amount of seconds in a day are: {SECONDS_PER_HOUR * HOURS_PER_DAY}")
# Out:
# The amount of seconds in a day are: 86400

# %% [markdown]
# 3.4
#
# Calculate seconds per day again, but this time save the result in a variable called seconds_per_day.

# %%
SECONDS_PER_DAY: int = SECONDS_PER_HOUR * HOURS_PER_DAY

# %% [markdown]
# 3.5
#
# Divide seconds_per_day by seconds_per_hour. Use floating-point (/) division.

# %%
print(f"Seconds per day divided by seconds per hour is: {SECONDS_PER_DAY/SECONDS_PER_HOUR:.2f}")
# Out:
# Seconds per day divided by seconds per hour is: 24.00

# %% [markdown]
# 3.6
#
# Divide seconds_per_day by seconds_per_hour, using integer (//) division. Did this number agree with the floating-point value from the previous question, aside from the final .0?

# %%
print(f"Seconds per day divided by seconds per hour is: {SECONDS_PER_DAY//SECONDS_PER_HOUR}")

#Yes it does agree as all this does is remove the floating point decials and not round.
# Out:
# Seconds per day divided by seconds per hour is: 24
